# %%
from langchain_openai import OpenAI
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
llm = OpenAI(model='gpt-3.5-turbo-instruct')

result = llm.invoke("Who is Virat Kohli ?")

print(result)
# Out:
# Virat Kohli is a professional Indian cricketer who is widely regarded as one of the greatest batsmen in the world. He was born on November 5, 1988 in Delhi, India and started his cricket career at a young age. He made his international debut in 2008 and has since become a key player for the Indian national team.
#
# Kohli is known for his aggressive and dynamic style of batting, scoring runs at a consistent rate across all formats of the game. He has broken numerous records and has won multiple awards and accolades, including being named ICC Cricketer of the Year in 2017 and 2018.
#
# Aside from his impressive cricket career, Kohli is also known for his philanthropy and advocacy for social causes. He is the co-owner of the Indian Super League football team FC Goa and has his own foundation, the Virat Kohli Foundation, which aims to support underprivileged children and promote sports in India.

# %%
result = llm.invoke("What is his DOB")

print(result)
# Out:
# ?
#
# Without knowing who "he" refers to, it is impossible to provide an accurate answer.

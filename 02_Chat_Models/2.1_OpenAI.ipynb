# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
model = ChatOpenAI(model='gpt-4')

result = model.invoke("What is the capital if India?")

print(result.content)
# Out:
# The capital of India is New Delhi.

# %%
model = ChatOpenAI(model='gpt-4', temperature=0.1, max_completion_tokens=30)

result = model.invoke("Write a 5 line poem on cricket")

print(result.content)
# Out:
# Cricket, a game of bat and ball,
# Under the sun, standing tall.
# Cheers echo as wickets fall,
# In this sport, loved by

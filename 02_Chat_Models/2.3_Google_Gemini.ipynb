# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
# import os

load_dotenv()

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

response = llm.invoke("Explain Virat Kohli in 30 words.")
print(response.content)
# Out:
# Virat Kohli: Modern cricketing legend. Aggressive run-scorer across formats, renowned for mastering run-chases. Batting prowess, passion, and records cement him as one of the greatest, a global icon.

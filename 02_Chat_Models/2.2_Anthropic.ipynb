# %% [markdown]
# Purchase credits on console.anthropic.com and get the API key.
#
# Then put it in .env file

# %%
from langchain_anthropic import ChatAnthropic
from dotenv import load_dotenv

load_dotenv()

model = ChatAnthropic(model='claude-3-5-sonnet-20241022')

result = model.invoke('What is the capital of India')

print(result.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[2], line 8
#       4 load_dotenv()
#       6 model = ChatAnthropic(model='claude-3-5-sonnet-20241022')
# ----> 8 result = model.invoke('What is the capital of India')
#      10 print(result.content)
#
# File e:\Data_Science\GenerativeAI\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File e:\Data_Science\GenerativeAI\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File e:\Data_Science\GenerativeAI\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File e:\Data_Science\GenerativeAI\myenv\Lib\site-packages\langchain_core\language_models\chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File e:\Data_Science\GenerativeAI\myenv\Lib\site-packages\langchain_anthropic\chat_models.py:1321, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1319     data = self._create(payload)
#    1320 except anthropic.BadRequestError as e:
# -> 1321     _handle_anthropic_bad_request(e)
#    1322 return self._format_output(data, **kwargs)
#
# File e:\Data_Science\GenerativeAI\myenv\Lib\site-packages\langchain_anthropic\chat_models.py:1319, in ChatAnthropic._generate(self, messages, stop, run_manager, **kwargs)
#    1317 payload = self._get_request_payload(messages, stop=stop, **kwargs)
#    1318 try:
# -> 1319     data = self._create(payload)
#    1320 except anthropic.BadRequestError as e:
#    1321     _handle_anthropic_bad_request(e)
#
# File e:\Data_Science\GenerativeAI\myenv\Lib\site-packages\langchain_anthropic\chat_models.py:1175, in ChatAnthropic._create(self, payload)
#    1173 if "betas" in payload:
#    1174     return self._client.beta.messages.create(**payload)
# -> 1175 return self._client.messages.create(**payload)
#
# File e:\Data_Science\GenerativeAI\myenv\Lib\site-packages\anthropic\_utils\_utils.py:282, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     280             msg = f"Missing required argument: {quote(missing[0])}"
#     281     raise TypeError(msg)
# --> 282 return func(*args, **kwargs)
#
# File e:\Data_Science\GenerativeAI\myenv\Lib\site-packages\anthropic\resources\messages\messages.py:930, in Messages.create(self, max_tokens, messages, model, metadata, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, extra_headers, extra_query, extra_body, timeout)
#     923 if model in DEPRECATED_MODELS:
#     924     warnings.warn(
#     925         f"The model '{model}' is deprecated and will reach end-of-life on {DEPRECATED_MODELS[model]}.\nPlease migrate to a newer model. Visit https://docs.anthropic.com/en/docs/resources/model-deprecations for more information.",
#     926         DeprecationWarning,
#     927         stacklevel=3,
#     928     )
# --> 930 return self._post(
#     931     "/v1/messages",
#     932     body=maybe_transform(
#     933         {
#     934             "max_tokens": max_tokens,
#     935             "messages": messages,
#     936             "model": model,
#     937             "metadata": metadata,
#     938             "service_tier": service_tier,
#     939             "stop_sequences": stop_sequences,
#     940             "stream": stream,
#     941             "system": system,
#     942             "temperature": temperature,
#     943             "thinking": thinking,
#     944             "tool_choice": tool_choice,
#     945             "tools": tools,
#     946             "top_k": top_k,
#     947             "top_p": top_p,
#     948         },
#     949         message_create_params.MessageCreateParamsStreaming
#     950         if stream
#     951         else message_create_params.MessageCreateParamsNonStreaming,
#     952     ),
#     953     options=make_request_options(
#     954         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     955     ),
#     956     cast_to=Message,
#     957     stream=stream or False,
#     958     stream_cls=Stream[RawMessageStreamEvent],
#     959 )
#
# File e:\Data_Science\GenerativeAI\myenv\Lib\site-packages\anthropic\_base_client.py:1326, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1312 def post(
#    1313     self,
#    1314     path: str,
#    (...)   1321     stream_cls: type[_StreamT] | None = None,
#    1322 ) -> ResponseT | _StreamT:
#    1323     opts = FinalRequestOptions.construct(
#    1324         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1325     )
# -> 1326     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File e:\Data_Science\GenerativeAI\myenv\Lib\site-packages\anthropic\_base_client.py:1114, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1111             err.response.read()
#    1113         log.debug("Re-raising status error")
# -> 1114         raise self._make_status_error_from_response(err.response) from None
#    1116     break
#    1118 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'Your credit balance is too low to access the Anthropic API. Please go to Plans & Billing to upgrade or purchase credits.'}, 'request_id': 'req_011CWTFSse5SMmD51hhzpbzp'}

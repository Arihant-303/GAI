# %%
from langchain_community.document_loaders import DirectoryLoader, PyPDFLoader

loader = DirectoryLoader(
    path='papers',
    glob='*.pdf',
    loader_cls=PyPDFLoader
)

# docs = loader.load()
# print(len(docs))
# print(docs[1].page_content)

docs = loader.lazy_load()

for document in docs:
    print(document.page_content[:100])  # Print first 100 characters of each document
    print(document.metadata)
# Out:
# 34
# BERT: Pre-training of Deep Bidirectional Transformers for
# Language Understanding
# Jacob Devlin Ming-W
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 0, 'page_label': '1'}
# word based only on its context. Unlike left-to-
# right language model pre-training, the MLM ob-
# jecti
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 1, 'page_label': '2'}
# BERT BERT
# E[CLS] E1  E[SEP]... EN E1’ ... EM’
# C
#  T1
#  T[SEP]...
#  TN
#  T1’ ...
#  TM’
# [CLS] Tok 1  [SEP].
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 2, 'page_label': '3'}
# Input/Output Representations To make BERT
# handle a variety of down-stream tasks, our input
# represent
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 3, 'page_label': '4'}
# [CLS] he likes play ##ing [SEP]my dog is cute [SEP]Input
# E[CLS] Ehe Elikes Eplay E##ing E[SEP]Emy Ed
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 4, 'page_label': '5'}
# System MNLI-(m/mm) QQP QNLI SST-2 CoLA STS-B MRPC RTE Average
# 392k 363k 108k 67k 8.5k 5.7k 3.5k 2.5k
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 5, 'page_label': '6'}
# System Dev Test
# EM F1 EM F1
# Top Leaderboard Systems (Dec 10th, 2018)
# Human - - 82.3 91.2
# #1 Ensemble
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 6, 'page_label': '7'}
# Dev Set
# Tasks MNLI-m QNLI MRPC SST-2 SQuAD
# (Acc) (Acc) (Acc) (Acc) (F1)
# BERTBASE 84.4 88.4 86.7 92.7
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 7, 'page_label': '8'}
# mixed results on the downstream task impact of
# increasing the pre-trained bi-LM size from two
# to fou
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 8, 'page_label': '9'}
# References
# Alan Akbik, Duncan Blythe, and Roland V ollgraf.
# 2018. Contextual string embeddings for s
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 9, 'page_label': '10'}
# Mandar Joshi, Eunsol Choi, Daniel S Weld, and Luke
# Zettlemoyer. 2017. Triviaqa: A large scale distan
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 10, 'page_label': '11'}
# for natural language understanding. In Proceedings
# of the 2018 EMNLP Workshop BlackboxNLP: An-
# alyzi
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 11, 'page_label': '1'}
# BERT (Ours)
# Trm Trm Trm
# Trm Trm Trm
# ...
# ...
# Trm Trm Trm
# Trm Trm Trm
# ...
# ...
# OpenAI GPT
# Lstm
# ELMo
# Lst
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 12, 'page_label': '2'}
# • Learning rate (Adam): 5e-5, 3e-5, 2e-5
# • Number of epochs: 2, 3, 4
# We also observed that large dat
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 13, 'page_label': '3'}
# BERT
# E[CLS] E1  E[SEP]... EN E1’ ... EM’
# C
#  T1
#  T[SEP]...
#  TN
#  T1’ ...
#  TM’
# [CLS] Tok
# 1
#  [SEP]... T
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 14, 'page_label': '4'}
# jority class.
# C Additional Ablation Studies
# C.1 Effect of Number of Training Steps
# Figure 5 presents
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-05-28T00:07:51+00:00', 'author': '', 'keywords': '', 'moddate': '2019-05-28T00:07:51+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\BERT_Research_Paper.pdf', 'total_pages': 16, 'page': 15, 'page_label': '5'}
# DistilBERT, a distilled version of BERT: smaller,
# faster, cheaper and lighter
# Victor SANH, Lysandre
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2020-03-03T01:35:16+00:00', 'author': '', 'keywords': '', 'moddate': '2020-03-03T01:35:16+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\DistilBert_Research_Paper.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1'}
# In this paper, we show that it is possible to reach similar performances on many downstream-tasks
# us
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2020-03-03T01:35:16+00:00', 'author': '', 'keywords': '', 'moddate': '2020-03-03T01:35:16+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\DistilBert_Research_Paper.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2'}
# Table 1: DistilBERT retains 97% of BERT performance. Comparison on the dev sets of the
# GLUE benchmar
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2020-03-03T01:35:16+00:00', 'author': '', 'keywords': '', 'moddate': '2020-03-03T01:35:16+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\DistilBert_Research_Paper.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3'}
# Table 4: Ablation study. Variations are relative to the model trained with triple loss and teacher
# w
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2020-03-03T01:35:16+00:00', 'author': '', 'keywords': '', 'moddate': '2020-03-03T01:35:16+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\DistilBert_Research_Paper.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4'}
# 6 Conclusion and future work
# We introduced DistilBERT, a general-purpose pre-trained version of BERT
# {'producer': 'pdfTeX-1.40.17', 'creator': 'LaTeX with hyperref package', 'creationdate': '2020-03-03T01:35:16+00:00', 'author': '', 'keywords': '', 'moddate': '2020-03-03T01:35:16+00:00', 'ptex.fullbanner': 'This is pdfTeX, Version 3.14159265-2.6-1.40.17 (TeX Live 2016) kpathsea version 6.2.2', 'subject': '', 'title': '', 'trapped': '/False', 'source': 'papers\\DistilBert_Research_Paper.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5'}
# arXiv:1907.11692v1  [cs.CL]  26 Jul 2019
# RoBERT a: A Robustly Optimized BERT Pretraining Approach
# Yi
# {'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-07-28T20:27:10-04:00', 'moddate': '2019-07-28T20:27:10-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'papers\\RoBERTa_Research_Paper.pdf', 'total_pages': 13, 'page': 0, 'page_label': '1'}
# alternatives that lead to better downstream task
# performance; (2) W e use a novel dataset, CC-
# NEW S
# {'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-07-28T20:27:10-04:00', 'moddate': '2019-07-28T20:27:10-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'papers\\RoBERTa_Research_Paper.pdf', 'total_pages': 13, 'page': 1, 'page_label': '2'}
# optimization hyperparameters, given in Section 2,
# except for the peak learning rate and number of
# wa
# {'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-07-28T20:27:10-04:00', 'moddate': '2019-07-28T20:27:10-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'papers\\RoBERTa_Research_Paper.pdf', 'total_pages': 13, 'page': 2, 'page_label': '3'}
# V2.0 some questions are not answered in the pro-
# vided context, making the task more challenging.
# Fo
# {'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-07-28T20:27:10-04:00', 'moddate': '2019-07-28T20:27:10-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'papers\\RoBERTa_Research_Paper.pdf', 'total_pages': 13, 'page': 3, 'page_label': '4'}
# Model SQuAD 1.1/2.0 MNLI-m SST -2 RACE
# Our reimplementation (with NSP loss):
# SEG M EN T -PA I R 90.4
# {'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-07-28T20:27:10-04:00', 'moddate': '2019-07-28T20:27:10-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'papers\\RoBERTa_Research_Paper.pdf', 'total_pages': 13, 'page': 4, 'page_label': '5'}
# bsz steps lr ppl MNLI-m SST -2
# 256 1M 1e-4 3.99 84.7 92.7
# 2K 125K 7e-4 3.68 85.2 92.9
# 8K 31K 1e-3 3.
# {'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-07-28T20:27:10-04:00', 'moddate': '2019-07-28T20:27:10-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'papers\\RoBERTa_Research_Paper.pdf', 'total_pages': 13, 'page': 5, 'page_label': '6'}
# Model data bsz steps SQuAD MNLI-m SST -2(v1.1/2.0)
# RoBERT a
# with B O O K S + W IK I 16GB 8K 100K 93.
# {'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-07-28T20:27:10-04:00', 'moddate': '2019-07-28T20:27:10-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'papers\\RoBERTa_Research_Paper.pdf', 'total_pages': 13, 'page': 6, 'page_label': '7'}
# MNLI QNLI QQP RTE SST MRPC CoLA STS WNLI A vg
# Single-task single models on dev
# BERTL A R G E 86.6/-
# {'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-07-28T20:27:10-04:00', 'moddate': '2019-07-28T20:27:10-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'papers\\RoBERTa_Research_Paper.pdf', 'total_pages': 13, 'page': 7, 'page_label': '8'}
# Model SQuAD 1.1 SQuAD 2.0
# EM F1 EM F1
# Single models on dev , w/o data augmentation
# BERTL A R G E 84.
# {'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-07-28T20:27:10-04:00', 'moddate': '2019-07-28T20:27:10-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'papers\\RoBERTa_Research_Paper.pdf', 'total_pages': 13, 'page': 8, 'page_label': '9'}
# 7 Conclusion
# W e carefully evaluate a number of design de-
# cisions when pretraining BERT models. W e
# {'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-07-28T20:27:10-04:00', 'moddate': '2019-07-28T20:27:10-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'papers\\RoBERTa_Research_Paper.pdf', 'total_pages': 13, 'page': 9, 'page_label': '10'}
# Mandar Joshi, Danqi Chen, Y inhan Liu, Daniel S.
# W eld, Luke Zettlemoyer, and Omer Levy. 2019.
# SpanB
# {'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-07-28T20:27:10-04:00', 'moddate': '2019-07-28T20:27:10-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'papers\\RoBERTa_Research_Paper.pdf', 'total_pages': 13, 'page': 10, 'page_label': '11'}
# Ashish V aswani, Noam Shazeer, Niki Parmar, Jakob
# Uszkoreit, Llion Jones, Aidan N Gomez, Łukasz
# Kais
# {'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-07-28T20:27:10-04:00', 'moddate': '2019-07-28T20:27:10-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'papers\\RoBERTa_Research_Paper.pdf', 'total_pages': 13, 'page': 11, 'page_label': '12'}
# MNLI QNLI QQP RTE SST MRPC CoLA STS
# RoBERT aBA S E
# + all data + 500k steps 87.6 92.8 91.9 78.7 94.8
# {'producer': 'dvips + GPL Ghostscript GIT PRERELEASE 9.22', 'creator': 'LaTeX with hyperref package', 'creationdate': '2019-07-28T20:27:10-04:00', 'moddate': '2019-07-28T20:27:10-04:00', 'title': '', 'subject': '', 'author': '', 'keywords': '', 'source': 'papers\\RoBERTa_Research_Paper.pdf', 'total_pages': 13, 'page': 12, 'page_label': '13'}
